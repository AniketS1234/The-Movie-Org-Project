# %% [markdown]
# # Data Visualization And Analysis Of The Movie Org DB

# %%
import pandas as pd
import numpy as np

# %%
 dataset = pd.read_csv("C://Users//NIKHIL//Downloads/Movies_DB2.csv",index_col=0)

# %%
dataset
# Out:
#                                                    Name  Rating  \
# 0                                  Sonic the Hedgehog 2    77.0
# 1                                            The Batman    78.0
# 2                                             Uncharted    72.0
# 3           Doctor Strange in the Multiverse of Madness    75.0
# 4                                          The Bad Guys    77.0
# ...                                                 ...     ...
# 2995  Naruto Shippuden: OVA Hashirama Senju vs Madar...    68.0
# 2996                                               TMNT    61.0
# 2997                                           The Mule    68.0
# 2998                                Herbie Fully Loaded    56.0
# 2999                                             Eiffel    63.0
#
#                                                   Genre Release date  \
# 0     Action, Science Fiction, Comedy, Family, Adven...   04/08/2022
# ...

# %%
pwd
# Out:
# 'C:\\Users\\NIKHIL\\Desktop\\Python Scripts\\Web Scrapping Movie DB'

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
import re

# %%
dataset.head(10)
# Out:
#                                           Name  Rating  \
# 0                         Sonic the Hedgehog 2    77.0
# 1                                   The Batman    78.0
# 2                                    Uncharted    72.0
# 3  Doctor Strange in the Multiverse of Madness    75.0
# 4                                 The Bad Guys    77.0
# 5                      Spider-Man: No Way Home    81.0
# 6                                    Ambulance    70.0
# 7                                  Turning Red    74.0
# 8                               Doctor Strange    74.0
# 9                                     Virus:32    67.0
#
#                                                Genre Release date  \
# 0  Action, Science Fiction, Comedy, Family, Adven...   04/08/2022
# 1                           Crime, Mystery, Thriller   03/04/2022
# 2                                  Action, Adventure   02/18/2022
# 3                         Fantasy, Action, Adventure   05/06/2022
# ...

# %%
dataset.tail(10)
# Out:
#                                                    Name  Rating  \
# 2990                                            Revenge    64.0
# 2991                    Scooby-Doo! and the Cyber Chase    74.0
# 2992                                         Ex Machina    76.0
# 2993                                          Footloose    66.0
# 2994                                             Amélie    79.0
# 2995  Naruto Shippuden: OVA Hashirama Senju vs Madar...    68.0
# 2996                                               TMNT    61.0
# 2997                                           The Mule    68.0
# 2998                                Herbie Fully Loaded    56.0
# 2999                                             Eiffel    63.0
#
#                                             Genre Release date  \
# 2990                     Action, Thriller, Horror   02/07/2018
# 2991                 Animation, Adventure, Comedy   10/09/2001
# 2992                       Drama, Science Fiction   01/21/2015
# ...

# %%
dataset.columns
# Out:
# Index(['Name', 'Rating', 'Genre', 'Release date', 'Runtime', 'Director',
#        'Url'],
#       dtype='object')

# %%
dataset.iloc[8]
# Out:
# Name                                         Doctor Strange
# Rating                                                 74.0
# Genre           Action, Adventure, Fantasy, Science Fiction
# Release date                                     11/04/2016
# Runtime                                    1h 55m
# Director                                   Scott Derrickson
# Url                 https://www.themoviedb.org/movie/284052
# Name: 8, dtype: object

# %%
dataset.iloc[2837]
# Out:
# Name                          Puff: Wonders of the Reef
# Rating                                             78.0
# Genre                                       Documentary
# Release date                                 12/16/2021
# Runtime                                   59m
# Director                                  Nick Robinson
# Url             https://www.themoviedb.org/movie/890601
# Name: 2837, dtype: object

# %% [markdown]
# # **Data of Movies Which Has Rating Less Than 50**

# %%
df = dataset[dataset['Rating'] < 50]

# %%
df
# Out:
#                                               Name  Rating  \
# 30                               The eighth clause    41.0
# 40                                      The Requin    47.0
# 84                                     The Hunting    49.0
# 121                                         Brazen    49.0
# 126                                       Tarumama    48.0
# ...                                            ...     ...
# 2873                       DC League of Super-Pets     0.0
# 2892                       Covet: Island of Desire    45.0
# 2893                                  Bullet Train     0.0
# 2896  UFC 274: Oliveira vs Gaethje - Early Prelims     0.0
# 2916          The Secret Lives of College Freshmen    20.0
#
#                                    Genre Release date  \
# 30                              Thriller   04/29/2022
# 40                              Thriller   01/28/2022
# 84                                Horror   01/21/2022
# ...

# %%
least_20 = df[['Name','Rating']]
least_20
# Out:
#                                               Name  Rating
# 30                               The eighth clause    41.0
# 40                                      The Requin    47.0
# 84                                     The Hunting    49.0
# 121                                         Brazen    49.0
# 126                                       Tarumama    48.0
# ...                                            ...     ...
# 2873                       DC League of Super-Pets     0.0
# 2892                       Covet: Island of Desire    45.0
# 2893                                  Bullet Train     0.0
# 2896  UFC 274: Oliveira vs Gaethje - Early Prelims     0.0
# 2916          The Secret Lives of College Freshmen    20.0
#
# [162 rows x 2 columns]

# %% [markdown]
# # Data Of Least 20 Movies Based On Ratings

# %%
least1_20 = least_20.sort_values(by='Rating', ascending=True)
least1_20 = least1_20[30:51]
least1_20
# Out:
#                                                    Name  Rating
# 1902                    Dragon Ball & Dr. Slump Special    20.0
# 2916               The Secret Lives of College Freshmen    20.0
# 1117                  Jurassic World Dominion: Prologue    20.0
# 1126  Marvel Studios: Assembled – The Making of Moon...    20.0
# 1633                                  August Never Ends    20.0
# 1520                              The Batman: Making-Of    20.0
# 1807                                               Hope    20.0
# 2149                 Kimetsu no Yaiba Orchestra Concert    20.0
# 834   Calendar Girl, Cop, Killer? The Bambi Bembenek...    20.0
# 1556                              1918: The Spanish Flu    20.0
# 814                          Female Doctor: Flesh Slave    20.0
# 2849                                         La Cantera    20.0
# 2808                             Goyo: En Letra de Otro    20.0
# 2641                                               Halo    20.0
# ...

# %% [markdown]
# # Least 20 Movies Based On Ratings

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
fig = plt.figure(figsize=(10,7))
sns.barplot(x = 'Name', y = 'Rating', data = least1_20).set(title = 'Least 20 Movies Based On The Ratings')
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# # Data of Movies Which Has Rating Greater Than 80

# %%
df1 = dataset[dataset['Rating'] > 80]

# %%
df1
# Out:
#                                                    Name  Rating  \
# 5                               Spider-Man: No Way Home    81.0
# 29    Demon Slayer -Kimetsu no Yaiba- The Movie: Mug...    84.0
# 34                                               Sing 2    81.0
# 79                               Avengers: Infinity War    83.0
# 91                                              Cruella    82.0
# ...                                                 ...     ...
# 2816                                    My Name Is Khan    81.0
# 2907                                             Joseph    83.0
# 2915                    One Flew Over the Cuckoo's Nest    84.0
# 2935                                              Jesus    83.0
# 2974          New Initial D the Movie - Legend 2: Racer    81.0
#
#                                       Genre Release date  \
# 5        Action, Adventure, Science Fiction   12/17/2021
# 29    Animation, Action, Adventure, Fantasy   08/13/2021
# ...

# %%
top_20 = df1[['Name','Rating']]
top_20
# Out:
#                                                    Name  Rating
# 5                               Spider-Man: No Way Home    81.0
# 29    Demon Slayer -Kimetsu no Yaiba- The Movie: Mug...    84.0
# 34                                               Sing 2    81.0
# 79                               Avengers: Infinity War    83.0
# 91                                              Cruella    82.0
# ...                                                 ...     ...
# 2816                                    My Name Is Khan    81.0
# 2907                                             Joseph    83.0
# 2915                    One Flew Over the Cuckoo's Nest    84.0
# 2935                                              Jesus    83.0
# 2974          New Initial D the Movie - Legend 2: Racer    81.0
#
# [153 rows x 2 columns]

# %% [markdown]
# # Data Of Top 20 Movies Based On Ratings

# %%
top1_20 = top_20.sort_values(by='Rating', ascending=False)
top1_20 = top1_20[0:21]
top1_20
# Out:
#                                                Name  Rating
# 743               Everything Everywhere All at Once    89.0
# 748   Demon Slayer: Kimetsu no Yaiba Sibling's Bond    88.0
# 896                                   The Godfather    87.0
# 2524                              Impossible Things    87.0
# 1110                       The Shawshank Redemption    87.0
# 591                       Burn the Stage: The Movie    87.0
# 1438                         The Godfather: Part II    86.0
# 1037                                 Your Eyes Tell    86.0
# 1750                               Schindler's List    86.0
# 619                                 The Dark Knight    85.0
# 1437                              Life Is Beautiful    85.0
# 442        Rascal Does Not Dream of a Dreaming Girl    85.0
# 2664                                     GoodFellas    85.0
# 568   The Lord of the Rings: The Return of the King    85.0
# 1253                                   Forrest Gump    85.0
# ...

# %% [markdown]
# # Top 20 Movies Based On Ratings

# %%
fig = plt.figure()
fig = plt.figure(figsize=(10,7))
sns.barplot(x = 'Name', y = 'Rating', data = top1_20).set(title = 'Top 20 Movies Based On The Ratings')
plt.xticks(rotation = 90)
plt.show()

# %%
dataset
# Out:
#                                                    Name  Rating  \
# 0                                  Sonic the Hedgehog 2    77.0
# 1                                            The Batman    78.0
# 2                                             Uncharted    72.0
# 3           Doctor Strange in the Multiverse of Madness    75.0
# 4                                          The Bad Guys    77.0
# ...                                                 ...     ...
# 2995  Naruto Shippuden: OVA Hashirama Senju vs Madar...    68.0
# 2996                                               TMNT    61.0
# 2997                                           The Mule    68.0
# 2998                                Herbie Fully Loaded    56.0
# 2999                                             Eiffel    63.0
#
#                                                   Genre Release date  \
# 0     Action, Science Fiction, Comedy, Family, Adven...   04/08/2022
# ...

# %%
df1 = df[0:11]
df1
# Out:
#                               Name  Rating  \
# 30               The eighth clause    41.0
# 40                      The Requin    47.0
# 84                     The Hunting    49.0
# 121                         Brazen    49.0
# 126                       Tarumama    48.0
# 128      Curious George: Cape Ahoy    24.0
# 146                     The Bubble    49.0
# 166  Dragon Ball Super: Super Hero     0.0
# 174        Jurassic World Dominion     0.0
# 185                        Demonic    48.0
# 199                  Jurassic Hunt    49.0
#
#                                             Genre Release date  \
# 30                                       Thriller   04/29/2022
# 40                                       Thriller   01/28/2022
# 84                                         Horror   01/21/2022
# 121                      Thriller, Mystery, Drama   01/13/2022
# 126                                 Horror, Drama   07/29/2021
# ...

# %%
dataset['Director'].unique()
# Out:
# array(['Jeff Fowler', 'Matt Reeves', 'Ruben Fleischer', ...,
#        'Kevin Munroe', 'Angela Robinson', 'Martin Bourboulon'],
#       dtype=object)

# %% [markdown]
# # Fetching Movie Names Which Has Single Genre Comedy Or Horror

# %%
ds = dataset[dataset['Genre'] == 'Comedy']
ds1 = dataset[dataset['Genre'] == 'Horror']

ds2 = ds.append(ds1)
ds2
# Out:
#                                   Name  Rating   Genre Release date  \
# 53            Honeymoon With My Mother    64.0  Comedy   04/29/2022
# 146                         The Bubble    49.0  Comedy   03/25/2022
# 152                     ¿Y cómo es él?    63.0  Comedy   04/07/2022
# 186               Un Rabón Con Corazón    66.0  Comedy   01/27/2022
# 188          S.O.S. Mamis: La película    59.0  Comedy   03/18/2022
# ...                                ...     ...     ...          ...
# 2801                        Sinister 2    58.0  Horror   08/21/2015
# 2807                            Amulet    55.0  Horror   01/28/2022
# 2812  Friday the 13th: A New Beginning    53.0  Horror   03/22/1985
# 2955                       3 from Hell    58.0  Horror   10/24/2019
# 2967                            Row 19    58.0  Horror   11/11/2021
#
#                              Runtime             Director  \
# 53                  1h 50m                 Paco Caballero
# ...

# %% [markdown]
# # Total No Of  Movies Count Based On Genre

# %%
plt.figure(figsize = (10,5))
sns.countplot(x = 'Genre' , data = ds2).set(title='Total No Of Counts Of Movie Based On Genre Comedy And Horror')
plt.ylabel('No.of Movies')
# Out:
# Text(0, 0.5, 'No.of Movies')

# %% [markdown]
# # Fetching Director Data

# %%
dataset['Director'].value_counts()
# Out:
# Steven Spielberg     15
# Tim Burton           13
# Ridley Scott         12
# Michael Bay          11
# Hayao Miyazaki       10
#                      ..
# Peter Billingsley     1
# Anna Foerster         1
# Jeff Tomsic           1
# Aleksey Tsitsilin     1
# Martin Bourboulon     1
# Name: Director, Length: 1900, dtype: int64

# %% [markdown]
# # Fetching Top2 Director Names With Most Movies Directed

# %%
ns = dataset[dataset['Director'] == 'Steven Spielberg']
ns1 = dataset[dataset['Director'] == 'Tim Burton']

ns2 = ns.append(ns1)
ns2
# Out:
#                                                    Name  Rating  \
# 219                                     West Side Story    72.0
# 398                                    Ready Player One    76.0
# 1461                                            The BFG    62.0
# 1658                                Saving Private Ryan    82.0
# 1715                                      Jurassic Park    79.0
# 1738                                               Jaws    76.0
# 1750                                   Schindler's List    86.0
# 2105                                Catch Me If You Can    80.0
# 2136                 Indiana Jones and the Last Crusade    78.0
# 2292                                  War of the Worlds    65.0
# 2371                         E.T. the Extra-Terrestrial    75.0
# 2420                            Raiders of the Lost Ark    79.0
# 2621               Indiana Jones and the Temple of Doom    73.0
# 2903  Indiana Jones and the Kingdom of the Crystal S...    60.0
# ...

# %%
plt.figure(figsize = (10,5))
sns.countplot(x = 'Director' , data = ns2).set(title='Top2 Director With Most Movies')
plt.ylabel('No.of Movies')
# Out:
# Text(0, 0.5, 'No.of Movies')

# %% [markdown]
# # Fetching Individual Director

# %%
mdr_tp = dataset[dataset['Director'] == 'Christopher Nolan']
mdr_tp = mdr_tp.sort_values(by = 'Rating' , ascending = False)
mdr_tp = mdr_tp
mdr_tp
# Out:
#                        Name  Rating                               Genre  \
# 619         The Dark Knight    85.0      Drama, Action, Crime, Thriller
# 397            Interstellar    84.0   Adventure, Drama, Science Fiction
# 512               Inception    84.0  Action, Science Fiction, Adventure
# 471   The Dark Knight Rises    78.0      Action, Crime, Drama, Thriller
# 793           Batman Begins    77.0                Action, Crime, Drama
# 2846                Dunkirk    75.0                  War, Action, Drama
# 593                   Tenet    72.0   Action, Thriller, Science Fiction
#
#      Release date                         Runtime           Director  \
# 619    07/18/2008                2h 32m            Christopher Nolan
# 397    11/07/2014                2h 49m            Christopher Nolan
# 512    07/16/2010                2h 28m            Christopher Nolan
# 471    07/20/2012                2h 45m            Christopher Nolan
# ...

# %% [markdown]
# # Director Christopher Nolan Top Movies Based On Ratings

# %%
fig = plt.figure()
fig = plt.figure(figsize=(10,7))
sns.barplot(x = 'Name' , y = 'Rating' , data = mdr_tp).set(title = ' Director Christopher Nolan Movies Based On Ratings')

plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# # Director Christopher Nolan Top 5 Movies Based On Ratings

# %%
mdr_tp1 = dataset[dataset['Director'] == 'Christopher Nolan']
mdr_tp1 = mdr_tp1.sort_values(by = 'Rating' , ascending = False)
mdr_tp1 = mdr_tp1[0:5]
mdr_tp1
# Out:
#                       Name  Rating                               Genre  \
# 619        The Dark Knight    85.0      Drama, Action, Crime, Thriller
# 397           Interstellar    84.0   Adventure, Drama, Science Fiction
# 512              Inception    84.0  Action, Science Fiction, Adventure
# 471  The Dark Knight Rises    78.0      Action, Crime, Drama, Thriller
# 793          Batman Begins    77.0                Action, Crime, Drama
#
#     Release date                         Runtime           Director  \
# 619   07/18/2008                2h 32m            Christopher Nolan
# 397   11/07/2014                2h 49m            Christopher Nolan
# 512   07/16/2010                2h 28m            Christopher Nolan
# 471   07/20/2012                2h 45m            Christopher Nolan
# 793   06/17/2005                2h 20m            Christopher Nolan
#
#                                          Url
# 619     https://www.themoviedb.org/movie/155
# ...

# %% [markdown]
# # HistPlot Showing Director Christopher Nolan Total Count Of Top 5 Movie Based On Ratings

# %%
sns.histplot(data = mdr_tp1, x = 'Rating', color='blue').set(title='Director Christopher Nolan Total No Of Movies Count Based On Ratings')
# Out:
# [Text(0.5, 1.0, 'Director Christopher Nolan Total No Of Movies Count Based On Ratings')]

# %% [markdown]
# # BarPlot Showing Director Christopher Nolan Movie Names With Their Respective Ratings

# %%
sns.barplot(x = 'Name' , y = 'Rating' , data = mdr_tp1).set(title = ' Director Christopher Nolan Top 5 Movies Based On Ratings')
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# # CountPlot Showing Director Christopher Nolan Total Count Of Different Movies Based On Genre

# %%
sns.countplot(x = 'Genre', data = mdr_tp).set(title = ' Director Christopher Nolan Movies Based On Different Genre')
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# # CountPlot Showing Director Christopher Nolan Movies Count Data Based On Rating

# %%
sns.countplot(x = 'Rating' , data = mdr_tp).set(title = ' Director Christopher Nolan Movies Based On Count Of  Ratings')
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# # Director Byron Howard Top Movies Based On Ratings

# %%
mdr_tp2 = dataset[dataset['Director'] == 'Byron Howard']
mdr_tp2 = mdr_tp2.sort_values(by = 'Rating' , ascending = False)
mdr_tp2 = mdr_tp2
mdr_tp2
# Out:
#                     Name  Rating                                 Genre  \
# 13               Encanto    77.0    Animation, Comedy, Family, Fantasy
# 572             Zootopia    77.0  Animation, Adventure, Family, Comedy
# 429              Tangled    76.0                     Animation, Family
# 2353  Tangled Ever After    71.0     Animation, Comedy, Action, Family
# 1078                Bolt    65.0  Animation, Family, Adventure, Comedy
#
#      Release date                         Runtime      Director  \
# 13     11/24/2021                1h 42m            Byron Howard
# 572    03/04/2016                1h 49m            Byron Howard
# 429    01/21/2011                1h 40m            Byron Howard
# 2353   01/13/2012                    6m            Byron Howard
# 1078   11/21/2008                1h 38m            Byron Howard
#
#                                           Url
# 13    https://www.themoviedb.org/movie/568124
# 572   https://www.themoviedb.org/movie/269149
# ...

# %% [markdown]
# # CountPlot Showing Director Byron Howard Movies Count Data Based On Rating

# %%
sns.countplot(x = 'Rating', data = mdr_tp2).set(title = ' Director Byron Howard Movies Count Based On Rating')
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# # LinePlot Showing Director Byron Howard Movies Names With  Total Movie Runtime

# %%
sns.lineplot(x = 'Name', y = 'Runtime',data = mdr_tp2)
# Out:
# <AxesSubplot:xlabel='Name', ylabel='Runtime'>

# %% [markdown]
# # BarPlot Showing Director Byron Howard Movie Names With Their Respective Ratings

# %%
sns.barplot(x = 'Name' , y = 'Rating' , data = mdr_tp2).set(title = ' Director Byron Howard Movies Based On Ratings')
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# # CountPlot Showing Director Byron Howard Count Of Different Movies Based On Genre

# %%
sns.countplot(x = 'Genre', data = mdr_tp2).set(title = ' Director Byron Howard Movies Based On Different Genre')
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# # Top 5 Movies Based On Single Genre Comedy

# %%
mr_ac = dataset[dataset['Genre'] == 'Comedy']
mr_ac = mr_ac.sort_values(by = 'Rating' , ascending = False)
mr_ac = mr_ac[0:5]
mr_ac
# Out:
#                              Name  Rating   Genre Release date  \
# 987                     El mesero    81.0  Comedy   07/15/2021
# 547            No Manches Frida 2    81.0  Comedy   03/15/2019
# 1833  Lokillo: Nothing's the Same    79.0  Comedy   08/12/2021
# 2045            We Are the Nobles    79.0  Comedy   03/28/2013
# 1685                 War of Likes    78.0  Comedy   03/12/2021
#
#                              Runtime             Director  \
# 987                 1h 26m                  Raúl Martínez
# 547                 1h 42m               Nacho G. Velilla
# 1833                 1h 4m            José Julián Gaviria
# 2045                1h 48m                  Gary Alazraki
# 1685                1h 43m                   María Ripoll
#
#                                           Url
# 987   https://www.themoviedb.org/movie/678580
# 547   https://www.themoviedb.org/movie/554596
# 1833  https://www.themoviedb.org/movie/857910
# 2045  https://www.themoviedb.org/movie/180147
# ...

# %% [markdown]
# # Top5 Comedy Movies Based On Ratings

# %%
fig = plt.figure()
fig = plt.figure(figsize=(8,5))
sns.scatterplot(x = 'Name' , y = 'Rating' ,hue='Release date',data = mr_ac).set(title = ' Top5 Movies Based On Comedy Genre With Rating')
plt.xticks(rotation = 90)
plt.show()

# %%
mr_a = dataset[dataset['Genre'] == 'Comedy']
mr_a = mr_a.sort_values(by = 'Rating' , ascending = True)
mr_a = mr_a[0:5]
mr_a
# Out:
#                           Name  Rating   Genre Release date  \
# 1634  Franco Escamilla: Clown!     0.0  Comedy   04/28/2022
# 362                 El Paseo 6    31.0  Comedy   12/25/2021
# 1842               Hole in One    41.0  Comedy   09/12/2009
# 1479             Jack and Jill    43.0  Comedy   11/11/2011
# 1111                  Movie 43    45.0  Comedy   01/25/2013
#
#                              Runtime            Director  \
# 1634                2h 36m              Franco Escamilla
# 362                 1h 37m                Rodrigo Triana
# 1842                1h 35m            Drew Ann Rosenberg
# 1479                1h 31m                  Dennis Dugan
# 1111                1h 30m                 Griffin Dunne
#
#                                           Url
# 1634  https://www.themoviedb.org/movie/960713
# 362   https://www.themoviedb.org/movie/920143
# 1842   https://www.themoviedb.org/movie/45781
# 1479   https://www.themoviedb.org/movie/71880
# ...

# %% [markdown]
# # Least5 Comedy Movies Based On Ratings

# %%
fig = plt.figure()
fig = plt.figure(figsize=(8,5))
sns.barplot(x = 'Name' , y = 'Rating',data = mr_a).set(title = ' Least5 Movies Based On Comedy Genre With Rating')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Top5 Drama Movies Based On Ratings

# %%
mr_ac1 = dataset[dataset['Genre'] == 'Drama']
mr_ac1 = mr_ac1.sort_values(by = 'Rating' , ascending = False)
mr_ac1 = mr_ac1[0:5]
mr_ac1
# Out:
#                                  Name  Rating  Genre Release date  \
# 2482                             Hope    85.0  Drama   10/02/2013
# 1222                       Fight Club    84.0  Drama   10/15/1999
# 2915  One Flew Over the Cuckoo's Nest    84.0  Drama   11/18/1975
# 2431               American History X    84.0  Drama   09/21/1999
# 2429                      Better Days    83.0  Drama   10/25/2019
#
#                              Runtime       Director  \
# 2482                 2h 2m              Lee Joon-ik
# 1222                2h 19m            David Fincher
# 2915                2h 13m             Miloš Forman
# 2431                1h 59m                Tony Kaye
# 2429                2h 15m              Derek Tsang
#
#                                           Url
# 2482  https://www.themoviedb.org/movie/255709
# 1222     https://www.themoviedb.org/movie/550
# 2915     https://www.themoviedb.org/movie/510
# 2431      https://www.themoviedb.org/movie/73
# ...

# %%
sns.barplot(x = 'Name' , y = 'Rating' , data = mr_ac1).set(title = ' Top5 Drama Movies Based On Rating')
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# # Count Of Total Number Of Genre Drama Movies Based On Rating

# %%
mr_ac2 = dataset[dataset['Genre'] == 'Drama']
mr_ac2 = mr_ac2.sort_values(by = 'Rating' , ascending = True)
mr_ac2 = mr_ac2[0:11]
mr_ac2
# Out:
#                             Name  Rating  Genre Release date  \
# 2849                  La Cantera    20.0  Drama   11/22/2021
# 2641                        Halo    20.0  Drama   06/01/2019
# 1827                 Sexo Animal    30.0  Drama   04/06/1983
# 1122        The Belly of the Sea    40.0  Drama   11/12/2021
# 2687  Dr. Kildare's Strange Case    42.0  Drama   04/12/1940
# 600                        Porno    43.0  Drama   01/01/1981
# 1864                      Tiempo    45.0  Drama   10/14/2020
# 2694                 All for Her    47.0  Drama   09/13/2021
# 1277             Skipping Stones    53.0  Drama   11/02/2021
# 459           The Penitent Thief    53.0  Drama   02/25/2021
# 2794    Nothing to Lose - Part 2    53.0  Drama   04/18/2019
#
#                              Runtime                Director  \
# 2849                1h 35m            Miguel Barreda-Delgado
# 2641                   16m            Michael-David McKernan
# ...

# %%
sns.countplot(x = 'Rating' , data = mr_ac2).set(title='Total No Of Drama Movie Count Based On Ratings')
plt.xticks(rotation = 90)
plt.show()

# %%
dataset['Genre'].value_counts().head(11)
# Out:
# Comedy                                112
# Drama                                 103
# Horror                                100
# Horror, Thriller                       80
# Comedy, Romance                        51
# Action, Thriller                       41
# Drama, Romance                         40
# Documentary                            40
# Animation, Family                      39
# Thriller                               34
# Action, Adventure, Science Fiction     31
# Name: Genre, dtype: int64

# %%
dataset['Genre'].value_counts()
# Out:
# Comedy                                         112
# Drama                                          103
# Horror                                         100
# Horror, Thriller                                80
# Comedy, Romance                                 51
#                                               ...
# Action, Science Fiction, Thriller, Western       1
# Crime, Drama, Mystery                            1
# Science Fiction, Fantasy, Action                 1
# Drama, Adventure, Science Fiction                1
# Comedy, Family, Adventure, Fantasy, Romance      1
# Name: Genre, Length: 1059, dtype: int64

# %%
rd = dataset.groupby('Release date')['Name' , 'Rating' , 'Runtime' , 'Director'].sum()
rd = rd.sort_values(by = 'Rating' , ascending = False)
rd = rd.head(15)
rd
# Out:
# C:\Users\NIKHIL\AppData\Local\Temp/ipykernel_11300/2122080219.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   rd = dataset.groupby('Release date')['Name' , 'Rating' , 'Runtime' , 'Director'].sum()
#               Rating
# Release date
# 10/08/2021     658.0
# 06/04/2021     601.0
# 10/01/2021     575.0
# 03/18/2022     560.0
# 04/08/2022     552.0
# 10/22/2021     549.0
# 08/20/2021     535.0
# 12/17/2021     519.0
# 11/24/2021     513.0
# 02/11/2022     509.0
# 02/24/2017     505.0
# 09/10/2021     502.0
# 08/06/2021     490.0
# 09/17/2021     480.0
# 12/03/2021     480.0

# %%
dataset['Release date'] = pd.to_datetime(dataset['Release date'])
dataset['Release date']
# Out:
# 0      2022-04-08
# 1      2022-03-04
# 2      2022-02-18
# 3      2022-05-06
# 4      2022-04-22
#           ...
# 2995   2012-02-23
# 2996   2007-03-23
# 2997   2018-12-14
# 2998   2005-06-22
# 2999   2021-10-13
# Name: Release date, Length: 3000, dtype: datetime64[ns]

# %%
dataset['Year'] = dataset['Release date'].dt.year
dataset
# Out:
#                                                    Name  Rating  \
# 0                                  Sonic the Hedgehog 2    77.0
# 1                                            The Batman    78.0
# 2                                             Uncharted    72.0
# 3           Doctor Strange in the Multiverse of Madness    75.0
# 4                                          The Bad Guys    77.0
# ...                                                 ...     ...
# 2995  Naruto Shippuden: OVA Hashirama Senju vs Madar...    68.0
# 2996                                               TMNT    61.0
# 2997                                           The Mule    68.0
# 2998                                Herbie Fully Loaded    56.0
# 2999                                             Eiffel    63.0
#
#                                                   Genre Release date  \
# 0     Action, Science Fiction, Comedy, Family, Adven...   2022-04-08
# ...

# %%
dataset['Year']
# Out:
# 0       2022
# 1       2022
# 2       2022
# 3       2022
# 4       2022
#         ...
# 2995    2012
# 2996    2007
# 2997    2018
# 2998    2005
# 2999    2021
# Name: Year, Length: 3000, dtype: int64

# %%
dt = dataset['Year'].value_counts()

# %%
dt
# Out:
# 2021    492
# 2022    199
# 2020    171
# 2019    159
# 2017    147
#        ...
# 1961      1
# 1941      1
# 1951      1
# 1950      1
# 1968      1
# Name: Year, Length: 73, dtype: int64

# %%
rd21 = dataset[dataset['Year'] == 2021]
r20 = dataset[dataset['Year'] == 2020]
r19 = dataset[dataset['Year'] == 2019]

rdm = rd21.append(r20)
rdm1 = rdm.append(r19)
rdm1
# Out:
#                                  Name  Rating  \
# 5             Spider-Man: No Way Home    81.0
# 13                            Encanto    77.0
# 20    War of the Worlds: Annihilation    56.0
# 24                   Pil's Adventures    68.0
# 25        Venom: Let There Be Carnage    70.0
# ...                               ...     ...
# 2829                             Burn    61.0
# 2842                     Batman: Hush    73.0
# 2850                         The King    72.0
# 2955                      3 from Hell    58.0
# 2980                             Anna    67.0
#
#                                                   Genre Release date  \
# 5                    Action, Adventure, Science Fiction   2021-12-17
# 13                   Animation, Comedy, Family, Fantasy   2021-11-24
# 20                              Science Fiction, Action   2021-12-22
# 24        Adventure, Animation, Comedy, Family, Fantasy   2021-08-11
# ...

# %%
sns.countplot(x='Year',data=rdm1)
plt.ylabel('Total No Of Movies')
# Out:
# Text(0, 0.5, 'Total No Of Movies')

# %%
rd_max = dataset.groupby('Year')['Name' , 'Rating' , 'Genre' , 'Runtime', 'Director'].max()
rd_max
# Out:
# C:\Users\NIKHIL\AppData\Local\Temp/ipykernel_11300/2845729853.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   rd_max = dataset.groupby('Year')['Name' , 'Rating' , 'Genre' , 'Runtime', 'Director'].max()
# C:\Users\NIKHIL\AppData\Local\Temp/ipykernel_11300/2845729853.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   rd_max = dataset.groupby('Year')['Name' , 'Rating' , 'Genre' , 'Runtime', 'Director'].max()
#                                    Name  Rating  \
# Year
# 1939                   The Wizard of Oz    76.0
# 1940                          Pinocchio    71.0
# 1941                              Dumbo    70.0
# 1942                 Reap the Wild Wind    70.0
# 1943  The Crime Doctor’s Strangest Case    40.0
# ...

# %% [markdown]
# # LinePlot Showing Top Rated Movies Based On Individual Year

# %%
sns.lineplot(data=rd_max, x='Year', y='Rating').set(title='Top Rated Movies Based On Year')
# Out:
# [Text(0.5, 1.0, 'Top Rated Movies Based On Year')]

# %%
rd_max1 = dataset.groupby('Year')['Name' , 'Rating' , 'Genre' , 'Runtime', 'Director'].max()
rd_max2 = rd_max1[0:10]
rd_max2
# Out:
# C:\Users\NIKHIL\AppData\Local\Temp/ipykernel_11300/1546394044.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   rd_max1 = dataset.groupby('Year')['Name' , 'Rating' , 'Genre' , 'Runtime', 'Director'].max()
# C:\Users\NIKHIL\AppData\Local\Temp/ipykernel_11300/1546394044.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   rd_max1 = dataset.groupby('Year')['Name' , 'Rating' , 'Genre' , 'Runtime', 'Director'].max()
#                                    Name  Rating  \
# Year
# 1939                   The Wizard of Oz    76.0
# 1940                          Pinocchio    71.0
# 1941                              Dumbo    70.0
# 1942                 Reap the Wild Wind    70.0
# 1943  The Crime Doctor’s Strangest Case    40.0
# ...

# %%
sns.pointplot(data=rd_max2, x='Name', y='Rating').set(title='Top10 Movies Based On Ratings')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Top Rated Movies Of 2021

# %%
rd21
# Out:
#                                  Name  Rating  \
# 5             Spider-Man: No Way Home    81.0
# 13                            Encanto    77.0
# 20    War of the Worlds: Annihilation    56.0
# 24                   Pil's Adventures    68.0
# 25        Venom: Let There Be Carnage    70.0
# ...                               ...     ...
# 2960                The World to Come    71.0
# 2964  The Guide to the Perfect Family    66.0
# 2967                           Row 19    58.0
# 2970                        Nomadland    73.0
# 2999                           Eiffel    63.0
#
#                                               Genre Release date  \
# 5                Action, Adventure, Science Fiction   2021-12-17
# 13               Animation, Comedy, Family, Fantasy   2021-11-24
# 20                          Science Fiction, Action   2021-12-22
# 24    Adventure, Animation, Comedy, Family, Fantasy   2021-08-11
# 25               Science Fiction, Action, Adventure   2021-10-01
# ...

# %%
rd21m = rd21.sort_values(by = 'Rating' , ascending = False)
rd21m1 = rd21m.head(10)
rd21m1
# Out:
#                                                    Name  Rating  \
# 2524                                  Impossible Things    87.0
# 29    Demon Slayer -Kimetsu no Yaiba- The Movie: Mug...    84.0
# 384              Evangelion: 3.0+1.0 Thrice Upon a Time    84.0
# 1723                                  A Dog Named Palma    83.0
# 111                        Zack Snyder's Justice League    83.0
# 685                              New Gods: Nezha Reborn    82.0
# 2716                                              Belle    82.0
# 2502                                         The Father    82.0
# 2247                    The House of Flowers: The Movie    82.0
# 91                                              Cruella    82.0
#
#                                             Genre Release date  \
# 2524                                Family, Drama   2021-06-17
# 29          Animation, Action, Adventure, Fantasy   2021-08-13
# 384     Animation, Action, Science Fiction, Drama   2021-03-08
# ...

# %%
sns.histplot(data=rd21m1, x='Name', y='Rating').set(title='Top10 Movies Of Year 2021 Based On Rating')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # LinePlot Shows The Top 10 Movie Of The Year 2021 Based On Rating

# %%
sns.pointplot(data=rd21m1, x = 'Name', y='Rating')
plt.xticks(rotation=90)
plt.show()

# %%
r20
# Out:
#                                             Name  Rating  \
# 28                            Sonic the Hedgehog    74.0
# 107   Deathstroke: Knights & Dragons - The Movie    69.0
# 144    Miraculous World: New York, United HeroeZ    83.0
# 155                        The Croods: A New Age    76.0
# 182                               Monster Hunter    68.0
# ...                                          ...     ...
# 2813                   Superman: Man of Tomorrow    73.0
# 2821                           The Invisible Man    72.0
# 2827                          Brahms: The Boy II    60.0
# 2838                              After We Leave    55.0
# 2985                                    Intruder    69.0
#
#                                                Genre Release date  \
# 28           Action, Science Fiction, Comedy, Family   2020-02-14
# 107    Animation, Action, Adventure, Science Fiction   2020-08-04
# 144   Animation, Family, Comedy, Adventure, TV Movie   2020-11-21
# ...

# %%
r20m = r20.sort_values(by = 'Rating' , ascending = False)
r20m1 = r20m.head(10)
r20m1
# Out:
#                                            Name  Rating  \
# 1037                             Your Eyes Tell    86.0
# 369                                       Given    85.0
# 833                                    Parasite    85.0
# 2228                  Primal: Tales of Savagery    84.0
# 1671         Justice League Dark: Apokolips War    84.0
# 144   Miraculous World: New York, United HeroeZ    83.0
# 1306                             Life in a Year    83.0
# 1317  Mortal Kombat Legends: Scorpion's Revenge    83.0
# 1850                                     Clouds    83.0
# 248                                        Soul    82.0
#
#                                                   Genre Release date  \
# 1037                                     Romance, Drama   2020-10-23
# 369                    Animation, Drama, Music, Romance   2020-08-22
# 833                             Comedy, Thriller, Drama   2020-01-31
# ...

# %% [markdown]
# # LinePlot Shows The Top 10 Movie Of The Year 2020 Based On Rating

# %%
sns.pointplot(data=r20m1, x = 'Name', y='Rating')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # CountPlot Shows The Total Count Of The Top Movies Of The Year 2020 Based On Their Ratings

# %%
sns.countplot(data=r20m1, x='Rating')
plt.ylabel("No Of Movies")
plt.show()

# %% [markdown]
# # CountPlot Shows The Total Count Of The Top Movies Of The Year 2021 Based On Their Ratings

# %%
sns.countplot(data=rd21m1, x='Rating')
plt.ylabel("No Of Movies")
plt.show()

# %%
dataset['Director'].value_counts().head(13)
# Out:
# Steven Spielberg      15
# Tim Burton            13
# Ridley Scott          12
# Michael Bay           11
# Hayao Miyazaki        10
# Antoine Fuqua         10
# Zack Snyder            9
# Shigeyasu Yamauchi     9
# Roland Emmerich        9
# William Lau            9
# M. Night Shyamalan     9
# Robert Rodriguez       9
# James Wan              9
# Name: Director, dtype: int64

# %%
x = df1.drop(['Annual Income (k$)','Segment','Age_Group','Generation'],axis=1)
